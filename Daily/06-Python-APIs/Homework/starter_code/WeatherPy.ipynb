# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
#from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#SET UP LISTS FOR DF
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

record = 1

print(f'Beginning Data Retrieval')
print(f'-----------------------------')

for city in cities:
    try:
        api_key="6f7c151e7ac5354bb8d35df742913a98"
        base_url="http://api.openweathermap.org/data/2.5/weather"   
        units="Imperial"
        PARAMS ={"APPID": api_key,
         "q": city,
         "units" : units}
        response=requests.get(url=base_url,params=PARAMS).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        print(f'Processing Record {record} | {city}')
        record = record + 1
    except KeyError:
        print(f'City not found. Skipping...')
    time.sleep(1)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | dryden
# Processing Record 2 | kamenka
# Processing Record 3 | barrow
# Processing Record 4 | golubitskaya
# Processing Record 5 | garden city
# Processing Record 6 | taoudenni
# Processing Record 7 | arraial do cabo
# Processing Record 8 | bredasdorp
# Processing Record 9 | kaitangata
# Processing Record 10 | ushuaia
# Processing Record 11 | padang
# Processing Record 12 | conceicao do araguaia
# Processing Record 13 | hobart
# Processing Record 14 | kibre mengist
# Processing Record 15 | vaini
# Processing Record 16 | vardo
# Processing Record 17 | komsomolskiy
# Processing Record 18 | rikitea
# Processing Record 19 | hammerfest
# Processing Record 20 | jamestown
# Processing Record 21 | bubaque
# Processing Record 22 | slave lake
# Processing Record 23 | tasiilaq
# Processing Record 24 | pisco
# Processing Record 25 | christchurch
# City not found. Skipping...
# Processing Record 26 | ponta do sol
# City not found. Skipping...
# Processing Record 27 | albany
# Processing Record 28 | saint-philippe
# Processing Record 29 | hithadhoo
# Processing Record 30 | diamantino
# Processing Record 31 | mar del plata
# Processing Record 32 | kapaa
# Processing Record 33 | mataura
# Processing Record 34 | punta arenas
# Processing Record 35 | tubuala
# Processing Record 36 | mahebourg
# Processing Record 37 | arenzano
# Processing Record 38 | upernavik
# Processing Record 39 | dharmavaram
# Processing Record 40 | hasaki
# Processing Record 41 | luganville
# Processing Record 42 | puerto ayora
# Processing Record 43 | guerrero negro
# City not found. Skipping...
# Processing Record 44 | severo-kurilsk
# Processing Record 45 | atuona
# City not found. Skipping...
# Processing Record 46 | aligudarz
# Processing Record 47 | kavieng
# Processing Record 48 | salinas
# Processing Record 49 | butaritari
# Processing Record 50 | dubovyy umet
# Processing Record 51 | knysna
# Processing Record 52 | adrar
# Processing Record 53 | hilo
# Processing Record 54 | bethel
# Processing Record 55 | avarua
# Processing Record 56 | georgetown
# Processing Record 57 | iwanai
# Processing Record 58 | lithgow
# Processing Record 59 | wagar
# Processing Record 60 | kamaishi
# Processing Record 61 | anadyr
# Processing Record 62 | tsaratanana
# Processing Record 63 | comodoro rivadavia
# Processing Record 64 | khudumelapye
# Processing Record 65 | bluff
# City not found. Skipping...
# Processing Record 66 | castro
# Processing Record 67 | luderitz
# Processing Record 68 | victoria
# Processing Record 69 | olinda
# Processing Record 70 | bam
# Processing Record 71 | port alfred
# City not found. Skipping...
# Processing Record 72 | yellowknife
# Processing Record 73 | bud
# Processing Record 74 | coihaique
# Processing Record 75 | busselton
# Processing Record 76 | hobyo
# Processing Record 77 | lompoc
# Processing Record 78 | zabol
# Processing Record 79 | cape town
# Processing Record 80 | trofors
# Processing Record 81 | la ronge
# Processing Record 82 | sangar
# Processing Record 83 | dhidhdhoo
# Processing Record 84 | tevaitoa
# Processing Record 85 | henties bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 86 | parana
# Processing Record 87 | axim
# Processing Record 88 | chernyakhovsk
# Processing Record 89 | san cristobal
# Processing Record 90 | port blair
# Processing Record 91 | claremore
# Processing Record 92 | east london
# Processing Record 93 | kannad
# Processing Record 94 | boguchany
# Processing Record 95 | garowe
# Processing Record 96 | meulaboh
# Processing Record 97 | seoul
# Processing Record 98 | new norfolk
# Processing Record 99 | normandin
# Processing Record 100 | zhigansk
# Processing Record 101 | harper
# City not found. Skipping...
# Processing Record 102 | itarema
# Processing Record 103 | lebu
# Processing Record 104 | longyearbyen
# Processing Record 105 | praya
# Processing Record 106 | narsaq
# City not found. Skipping...
# Processing Record 107 | maningrida
# Processing Record 108 | chokurdakh
# Processing Record 109 | marathon
# Processing Record 110 | nikolskoye
# Processing Record 111 | port pirie
# Processing Record 112 | fereydun kenar
# Processing Record 113 | khatanga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 114 | bandipur
# Processing Record 115 | bundibugyo
# Processing Record 116 | tiksi
# Processing Record 117 | chimbote
# Processing Record 118 | miram shah
# Processing Record 119 | peace river
# Processing Record 120 | kiunga
# Processing Record 121 | celestun
# Processing Record 122 | san policarpo
# Processing Record 123 | flinders
# Processing Record 124 | airai
# Processing Record 125 | el sobrante
# City not found. Skipping...
# Processing Record 126 | naze
# Processing Record 127 | tuatapere
# Processing Record 128 | thompson
# Processing Record 129 | high level
# Processing Record 130 | vila franca do campo
# Processing Record 131 | dikson
# Processing Record 132 | esperance
# Processing Record 133 | shanghai
# Processing Record 134 | byron bay
# Processing Record 135 | klaksvik
# Processing Record 136 | lyuban
# Processing Record 137 | kibala
# Processing Record 138 | nome
# Processing Record 139 | yumen
# City not found. Skipping...
# Processing Record 140 | qaqortoq
# Processing Record 141 | lagos
# Processing Record 142 | mandera
# Processing Record 143 | opole
# Processing Record 144 | iqaluit
# Processing Record 145 | marrakesh
# Processing Record 146 | san juan
# Processing Record 147 | umm lajj
# City not found. Skipping...
# Processing Record 148 | cherdyn
# Processing Record 149 | hermanus
# Processing Record 150 | tongren
# Processing Record 151 | sainte-rose
# Processing Record 152 | hami
# Processing Record 153 | yuxia
# Processing Record 154 | tuktoyaktuk
# Processing Record 155 | saskylakh
# Processing Record 156 | maniitsoq
# Processing Record 157 | kalabo
# Processing Record 158 | nynashamn
# Processing Record 159 | silver city
# Processing Record 160 | vestmanna
# Processing Record 161 | gorbatovka
# Processing Record 162 | saldanha
# City not found. Skipping...
# Processing Record 163 | kasane
# Processing Record 164 | kandalaksha
# Processing Record 165 | verkh-usugli
# Processing Record 166 | tautira
# Processing Record 167 | faanui
# City not found. Skipping...
# Processing Record 168 | provideniya
# Processing Record 169 | grindavik
# City not found. Skipping...
# Processing Record 170 | pachino
# Processing Record 171 | juventino rosas
# Processing Record 172 | kodiak
# City not found. Skipping...
# Processing Record 173 | vieux-habitants
# Processing Record 174 | geraldton
# Processing Record 175 | tromso
# Processing Record 176 | bambous virieux
# City not found. Skipping...
# Processing Record 177 | marawi
# Processing Record 178 | linxia
# Processing Record 179 | whitecourt
# Processing Record 180 | elko
# City not found. Skipping...
# Processing Record 181 | bridlington
# Processing Record 182 | lewisporte
# Processing Record 183 | ossora
# Processing Record 184 | qaanaaq
# Processing Record 185 | puerto colombia
# Processing Record 186 | carnarvon
# Processing Record 187 | talara
# Processing Record 188 | te anau
# Processing Record 189 | constitucion
# Processing Record 190 | awbari
# Processing Record 191 | mildura
# Processing Record 192 | koslan
# Processing Record 193 | bargarh
# Processing Record 194 | ola
# Processing Record 195 | chuy
# City not found. Skipping...
# Processing Record 196 | novikovo
# Processing Record 197 | nouadhibou
# Processing Record 198 | dalby
# Processing Record 199 | garmsar
# Processing Record 200 | heihe
# Processing Record 201 | port elizabeth
# Processing Record 202 | katsuura
# Processing Record 203 | morehead
# City not found. Skipping...
# Processing Record 204 | pyshchug
# Processing Record 205 | leshukonskoye
# Processing Record 206 | semey
# Processing Record 207 | sasciori
# Processing Record 208 | cidreira
# Processing Record 209 | margate
# Processing Record 210 | bathsheba
# City not found. Skipping...
# Processing Record 211 | obrnice
# Processing Record 212 | oyem
# Processing Record 213 | ribeira grande
# Processing Record 214 | bima
# City not found. Skipping...
# Processing Record 215 | ixtlan del rio
# Processing Record 216 | igarka
# City not found. Skipping...
# Processing Record 217 | mazabuka
# Processing Record 218 | chulman
# Processing Record 219 | pandan
# Processing Record 220 | lasa
# Processing Record 221 | banjar
# Processing Record 222 | lorengau
# City not found. Skipping...
# Processing Record 223 | coquimbo
# Processing Record 224 | huarmey
# Processing Record 225 | mpongwe
# Processing Record 226 | namatanai
# Processing Record 227 | mahon
# Processing Record 228 | goure
# Processing Record 229 | pizhma
# Processing Record 230 | tucuman
# Processing Record 231 | xichang
# Processing Record 232 | alghero
# Processing Record 233 | kruisfontein
# Processing Record 234 | aginskoye
# City not found. Skipping...
# Processing Record 235 | eureka
# Processing Record 236 | talnakh
# Processing Record 237 | kondinskoye
# Processing Record 238 | broken hill
# Processing Record 239 | hambantota
# Processing Record 240 | pimentel
# Processing Record 241 | yulara
# Processing Record 242 | cordoba
# Processing Record 243 | ancud
# Processing Record 244 | los zacatones
# City not found. Skipping...
# Processing Record 245 | saint george
# Processing Record 246 | isangel
# Processing Record 247 | batticaloa
# Processing Record 248 | la palma
# Processing Record 249 | bandar-e lengeh
# City not found. Skipping...
# Processing Record 250 | erenhot
# Processing Record 251 | las vegas
# Processing Record 252 | nuuk
# Processing Record 253 | kununurra
# Processing Record 254 | nanakuli
# Processing Record 255 | troutdale
# Processing Record 256 | alexandria
# Processing Record 257 | pontes e lacerda
# Processing Record 258 | dakoro
# Processing Record 259 | port hedland
# Processing Record 260 | alihe
# Processing Record 261 | kushima
# Processing Record 262 | touros
# Processing Record 263 | leningradskiy
# Processing Record 264 | at-bashi
# Processing Record 265 | spearfish
# Processing Record 266 | kralendijk
# Processing Record 267 | altamira
# Processing Record 268 | valley city
# Processing Record 269 | sao filipe
# Processing Record 270 | ust-ilimsk
# Processing Record 271 | hohhot
# Processing Record 272 | eatonton
# Processing Record 273 | ulaanbaatar
# Processing Record 274 | seymchan
# Processing Record 275 | norman wells
# Processing Record 276 | molteno
# Processing Record 277 | northam
# Processing Record 278 | wuning
# Processing Record 279 | pangoa
# Processing Record 280 | srednekolymsk
# Processing Record 281 | road town
# Processing Record 282 | clyde river
# City not found. Skipping...
# Processing Record 283 | la paz
# City not found. Skipping...
# Processing Record 284 | hofn
# City not found. Skipping...
# Processing Record 285 | scarborough
# Processing Record 286 | souillac
# Processing Record 287 | raudeberg
# Processing Record 288 | newport
# Processing Record 289 | laguna
# Processing Record 290 | yenagoa
# Processing Record 291 | matara
# Processing Record 292 | hualmay
# Processing Record 293 | cam ranh
# Processing Record 294 | surgut
# Processing Record 295 | ayan
# Processing Record 296 | rundu
# Processing Record 297 | agua verde
# City not found. Skipping...
# Processing Record 298 | paita
# Processing Record 299 | faya
# Processing Record 300 | nara
# City not found. Skipping...
# Processing Record 301 | redmond
# Processing Record 302 | salalah
# Processing Record 303 | sola
# Processing Record 304 | fonte boa
# Processing Record 305 | brae
# Processing Record 306 | cabo san lucas
# Processing Record 307 | ocean city
# Processing Record 308 | vao
# Processing Record 309 | roblin
# Processing Record 310 | kulhudhuffushi
# Processing Record 311 | zatoka
# Processing Record 312 | ketchikan
# Processing Record 313 | ilulissat
# City not found. Skipping...
# Processing Record 314 | hervey bay
# Processing Record 315 | baghdad
# Processing Record 316 | visby
# Processing Record 317 | loa janan
# City not found. Skipping...
# Processing Record 318 | tiarei
# Processing Record 319 | stavern
# Processing Record 320 | half moon bay
# Processing Record 321 | moultrie
# Processing Record 322 | maua
# Processing Record 323 | eyl
# Processing Record 324 | yuncheng
# Processing Record 325 | kloulklubed
# Processing Record 326 | port-cartier
# Processing Record 327 | yinchuan
# Processing Record 328 | maldonado
# Processing Record 329 | owasso
# Processing Record 330 | necochea
# Processing Record 331 | key west
# Processing Record 332 | heidenau
# Processing Record 333 | oranjemund
# Processing Record 334 | shache
# Processing Record 335 | sitka
# Processing Record 336 | veraval
# Processing Record 337 | erdaojiang
# Processing Record 338 | dimapur
# Processing Record 339 | solnechnyy
# Processing Record 340 | port macquarie
# Processing Record 341 | sinnamary
# Processing Record 342 | kyren
# Processing Record 343 | quatre cocos
# Processing Record 344 | havoysund
# Processing Record 345 | tariba
# Processing Record 346 | torbay
# Processing Record 347 | hamilton
# Processing Record 348 | iranshahr
# Processing Record 349 | skelleftea
# Processing Record 350 | energetik
# Processing Record 351 | turbat
# Processing Record 352 | boddam
# Processing Record 353 | chute-aux-outardes
# Processing Record 354 | buzmeyin
# Processing Record 355 | husavik
# Processing Record 356 | batemans bay
# City not found. Skipping...
# Processing Record 357 | bogorodskoye
# Processing Record 358 | sobolevo
# Processing Record 359 | kondagaon
# Processing Record 360 | bowen
# Processing Record 361 | alyangula
# Processing Record 362 | kavaratti
# Processing Record 363 | ponta delgada
# Processing Record 364 | tazovskiy
# Processing Record 365 | pochutla
# Processing Record 366 | los llanos de aridane
# Processing Record 367 | zaykovo
# Processing Record 368 | devils lake
# Processing Record 369 | selkirk
# Processing Record 370 | lubango
# Processing Record 371 | yangjiang
# Processing Record 372 | tougue
# Processing Record 373 | gizo
# Processing Record 374 | inverell
# Processing Record 375 | baruun-urt
# Processing Record 376 | simao
# City not found. Skipping...
# Processing Record 377 | antalaha
# Processing Record 378 | sekoma
# Processing Record 379 | ahipara
# City not found. Skipping...
# Processing Record 380 | grand gaube
# Processing Record 381 | cabedelo
# Processing Record 382 | nicoya
# Processing Record 383 | vestmannaeyjar
# Processing Record 384 | boende
# City not found. Skipping...
# Processing Record 385 | vuktyl
# Processing Record 386 | manggar
# Processing Record 387 | fort-shevchenko
# Processing Record 388 | purna
# Processing Record 389 | lavrentiya
# Processing Record 390 | hay river
# Processing Record 391 | libreville
# Processing Record 392 | marzuq
# Processing Record 393 | springfield
# Processing Record 394 | novooleksiyivka
# Processing Record 395 | worland
# Processing Record 396 | andapa
# City not found. Skipping...
# Processing Record 397 | muzhi
# Processing Record 398 | boyolangu
# Processing Record 399 | zalesovo
# City not found. Skipping...
# Processing Record 400 | leh
# Processing Record 401 | nishihara
# Processing Record 402 | diebougou
# Processing Record 403 | nioro
# Processing Record 404 | port maria
# Processing Record 405 | mucurapo
# Processing Record 406 | nizwa
# Processing Record 407 | buraydah
# Processing Record 408 | erzin
# Processing Record 409 | san pedro
# Processing Record 410 | marabba
# Processing Record 411 | sabang
# Processing Record 412 | fairbanks
# Processing Record 413 | corn island
# Processing Record 414 | kollam
# City not found. Skipping...
# Processing Record 415 | abha
# Processing Record 416 | lata
# Processing Record 417 | pacific grove
# Processing Record 418 | santa ana
# Processing Record 419 | abay
# Processing Record 420 | fortuna
# Processing Record 421 | sevres
# Processing Record 422 | ikwiriri
# Processing Record 423 | college
# Processing Record 424 | mount gambier
# Processing Record 425 | nefteyugansk
# Processing Record 426 | port hardy
# Processing Record 427 | tunceli
# Processing Record 428 | vila velha
# Processing Record 429 | otukpo
# Processing Record 430 | jackson
# Processing Record 431 | anantapur
# Processing Record 432 | villa bruzual
# Processing Record 433 | okhotsk
# Processing Record 434 | gemenele
# Processing Record 435 | pita
# Processing Record 436 | novobirilyussy
# Processing Record 437 | wanaka
# Processing Record 438 | saint anthony
# Processing Record 439 | waverly
# Processing Record 440 | xiaoyi
# Processing Record 441 | longonjo
# Processing Record 442 | kargasok
# City not found. Skipping...
# Processing Record 443 | havelock
# Processing Record 444 | kyshtovka
# Processing Record 445 | alice springs
# Processing Record 446 | inuvik
# Processing Record 447 | morro bay
# Processing Record 448 | sakhnovshchyna
# Processing Record 449 | tutoia
# City not found. Skipping...
# Processing Record 450 | joshimath
# Processing Record 451 | kanniyakumari
# Processing Record 452 | san jose
# Processing Record 453 | pathein
# Processing Record 454 | edson
# Processing Record 455 | jiuquan
# Processing Record 456 | fuerte olimpo
# Processing Record 457 | borogontsy
# Processing Record 458 | lagoa
# Processing Record 459 | biak
# City not found. Skipping...
# Processing Record 460 | kenai
# Processing Record 461 | motril
# Processing Record 462 | dera bugti
# Processing Record 463 | san patricio
# Processing Record 464 | tiznit
# Processing Record 465 | aklavik
# Processing Record 466 | berdigestyakh
# Processing Record 467 | turukhansk
# Processing Record 468 | traverse city
# Processing Record 469 | coahuayana
# Processing Record 470 | bilibino
# Processing Record 471 | xining
# Processing Record 472 | curvelo
# City not found. Skipping...
# Processing Record 473 | kaffrine
# Processing Record 474 | jawhar
# Processing Record 475 | whitianga
# Processing Record 476 | orlik
# Processing Record 477 | nelspruit
# Processing Record 478 | urubamba
# Processing Record 479 | buala
# Processing Record 480 | bayangol
# Processing Record 481 | kwinana
# Processing Record 482 | alta floresta
# Processing Record 483 | port lincoln
# Processing Record 484 | tambo
# Processing Record 485 | benjamin constant
# Processing Record 486 | caravelas
# Processing Record 487 | gumla
# Processing Record 488 | gerash
# Processing Record 489 | sulphur
# Processing Record 490 | kahului
# Processing Record 491 | pangnirtung
# Processing Record 492 | ishikawa
# Processing Record 493 | sambava
# Processing Record 494 | san martin
# Processing Record 495 | paeroa
# Processing Record 496 | alofi
# Processing Record 497 | kaputa
# Processing Record 498 | lodja
# Processing Record 499 | gao
# Processing Record 500 | paamiut
# Processing Record 501 | vanimo
# Processing Record 502 | bikin
# Processing Record 503 | kalmunai
# Processing Record 504 | chiang klang
# Processing Record 505 | bajil
# Processing Record 506 | vigrestad
# Processing Record 507 | the valley
# Processing Record 508 | rio gallegos
# Processing Record 509 | ekhabi
# City not found. Skipping...
# Processing Record 510 | hlukhiv
# Processing Record 511 | haines junction
# Processing Record 512 | kawalu
# City not found. Skipping...
# Processing Record 513 | oistins
# Processing Record 514 | bilma
# Processing Record 515 | wanning
# City not found. Skipping...
# Processing Record 516 | bedele
# City not found. Skipping...
# Processing Record 517 | neustadt
# Processing Record 518 | codrington
# Processing Record 519 | north bend
# Processing Record 520 | mujiayingzi
# Processing Record 521 | ampanihy
# Processing Record 522 | abalak
# Processing Record 523 | kaohsiung
# City not found. Skipping...
# Processing Record 524 | gat
# City not found. Skipping...
# Processing Record 525 | tura
# City not found. Skipping...
# Processing Record 526 | ozimek
# Processing Record 527 | fort nelson
# Processing Record 528 | takoradi
# Processing Record 529 | bonavista
# Processing Record 530 | port-gentil
# Processing Record 531 | acapulco
# Processing Record 532 | saint-pierre
# Processing Record 533 | vysokogornyy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 534 | svetlaya
# Processing Record 535 | fare
# Processing Record 536 | beira
# Processing Record 537 | yerofey pavlovich
# Processing Record 538 | wanganui
# Processing Record 539 | pacocha
# Processing Record 540 | saint-augustin
# Processing Record 541 | teeli
# Processing Record 542 | beringovskiy
# Processing Record 543 | inongo
# Processing Record 544 | wilmington
# Processing Record 545 | namibe
# Processing Record 546 | booue
# Processing Record 547 | shenjiamen
# Processing Record 548 | chapada dos guimaraes
# Processing Record 549 | udachnyy
# Processing Record 550 | kabare
# Processing Record 551 | mogadishu
# Processing Record 552 | pevek
# City not found. Skipping...
# Processing Record 553 | mocuba
# Processing Record 554 | gangtok
# Processing Record 555 | vostok
# Processing Record 556 | trollhattan
# Processing Record 557 | acaponeta
# Processing Record 558 | abu samrah
# Processing Record 559 | honiara
# Processing Record 560 | dongli
# City not found. Skipping...
# Processing Record 561 | natal
# Processing Record 562 | portland
# Processing Record 563 | cururupu
# Processing Record 564 | yeniseysk

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame({"City": city_name,
                         "Cloudiness": cloudiness,
                         "Country": country, 
                         "Date": date,
                         "Humidity": humidity,
                         "Lat": lat,
                         "Lng": lng,
                         "Max Temp": max_temp,
                         "Wind Speed": wind_speed})

city_data.to_csv("city_data.csv")

city_data.count()
# Out:
# City          564
# Cloudiness    564
# Country       564
# Date          564
# Humidity      564
# Lat           564
# Lng           564
# Max Temp      564
# Wind Speed    564
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot
#
# print("hello")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
